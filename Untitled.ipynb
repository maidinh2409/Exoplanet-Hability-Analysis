# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery

# %%
client = bigquery.Client()

query = "SELECT * FROM `asteroid-db-456716.exoplanet_habitability_db.join_pl_star`"

df = client.query(query).to_dataframe()
df
# Out:
#                             planet_id   planet_name         mass     radius  \
# 0                         11COMB11COM      11 Com b   776.132328  12.200000
# 1                      HD145675C14HER   HD 145675 c  1597.087745  12.900000
# 2                         14HERB14HER      14 Her b  2559.472162  12.600000
# 3                         24BOOB24BOO      24 Boo b   776.132328  13.900000
# 4     KEPLER451C2MASSJ193832604603591  Kepler-451 c   776.132328  13.500000
# ...                               ...           ...          ...        ...
# 5921                KEPLER95BKEPLER95   Kepler-95 b    13.000000   3.420000
# 5922                  TOI1685BTOI1685    TOI-1685 b     3.030000   1.468000
# 5923                  TOI2373BTOI2373    TOI-2373 b  2955.804185  10.424352
# 5924                  TOI2714BTOI2714    TOI-2714 b   228.000000  13.720000
# 5925                  TOI6008BTOI6008    TOI-6008 b     4.000000   1.030000
#
# ...

# %%
df = df[['mass', 'radius', 'density', 't_eq', 'flux', 'distance_to_star', 
         'period', 'esi', 'habitable_score', 'temperature', 
         'st_rad', 'st_mass', 'st_metalicity', 'st_lum', 'st_subclass']]
df
# Out:
#              mass     radius    density         t_eq        flux  \
# 0      776.132328  12.200000  14.900000   912.839775  419.601461
# 1     1597.087745  12.900000   4.090000   912.839775  419.601461
# 2     2559.472162  12.600000   7.030000   912.839775  419.601461
# 3      776.132328  13.900000   0.574000   912.839775  419.601461
# 4      776.132328  13.500000   1.140000   912.839775  419.601461
# ...           ...        ...        ...          ...         ...
# 5921    13.000000   3.420000   1.710000   927.000000  178.832000
# 5922     3.030000   1.468000   5.300000  1062.000000  236.000000
# 5923  2955.804185  10.424352  14.400000   860.000000   69.872600
# 5924   228.000000  13.720000   0.490000  1603.000000  945.550000
# 5925     4.000000   1.030000   4.822593   707.000000   41.500000
#
#       distance_to_star        period       esi  habitable_score  temperature  \
# 0             1.178000    323.210000  0.075219              0.0       4874.0
# ...

# %%
df.describe()
# Out:
#               mass       radius      density         t_eq          flux  \
# count  5926.000000  5926.000000  5926.000000  5926.000000   5926.000000
# mean    776.132328     5.760603     4.822593   912.839775    419.601461
# std     924.578403     5.317795    34.054633   399.959766   1114.335777
# min       0.020000     0.309800     0.005100    34.000000      0.000300
# 25%     435.742746     1.820000     1.341750   658.000000     45.714300
# 50%     776.132328     2.830000     2.610000   912.839775    293.187000
# 75%     776.132328    11.898182     4.710000  1015.000000    419.601461
# max    9344.155166    77.342100  2000.000000  4050.000000  44900.000000
#
#        distance_to_star        period          esi  habitable_score  \
# count       5926.000000  5.926000e+03  5926.000000      5926.000000
# mean           3.103854  7.600106e+04     0.224994         0.040440
# std           31.907953  5.224518e+06     0.133885         0.203935
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                       mass    radius   density      t_eq      flux  \
# mass              1.000000  0.217653  0.153437  0.084386  0.033084
# radius            0.217653  1.000000 -0.043454  0.332892  0.200784
# density           0.153437 -0.043454  1.000000  0.001637 -0.000732
# t_eq              0.084386  0.332892  0.001637  1.000000  0.544488
# flux              0.033084  0.200784 -0.000732  0.544488  1.000000
# distance_to_star  0.357568  0.131579  0.019709  0.142041 -0.000798
# period            0.028031  0.018511  0.001006 -0.013908 -0.000001
# esi              -0.177483 -0.748083  0.022409 -0.470339 -0.185277
# habitable_score  -0.000261  0.006903 -0.009717 -0.167690 -0.039051
# temperature       0.022351  0.020287  0.002750  0.156862  0.094123
# st_rad            0.056675  0.203210  0.013992  0.043583  0.024615
# st_mass           0.098581  0.282493  0.001335  0.282794  0.177570
# st_metalicity    -0.013122  0.174364 -0.026491  0.139409  0.063760
# ...
